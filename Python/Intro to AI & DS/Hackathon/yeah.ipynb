# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
import nltk
import spacy
import sklearn

from datasets import load_dataset, Dataset

df = pd.read_csv('dataset.csv')
df
# Out:
#       Id                                               Text    Language  \
# 0      1  New iPhone 13 features are amazing! Can't wait...     English
# 1      2  Battery life of the new smartphone is disappoi...     English
# 2      3  Tesla's new solar panels are revolutionizing r...     English
# 3      4  Planting trees is crucial for fighting climate...     English
# 4      5  Makin berkembangnya teknologi, semakin mudah k...  Indonesian
# ..   ...                                                ...         ...
# 303  304  Penggunaan teknologi analisis citra drone dan ...  Indonesian
# 304  305  The advancement of hydrogen fuel cell technolo...     English
# 305  306  Inovasi dalam teknologi peningkatan produktivi...  Indonesian
# 306  307  The adoption of energy-efficient building desi...     English
# 307  308  Teknologi konservasi air, seperti pengumpulan ...  Indonesian
#
#      Retweets  Favorites                  User
# 0         120         85              @user123
# 1          55         20            @techlover
# 2          90         40       @greenenergyfan
# 3          75         30       @climatewarrior
# 4         110         80            @pengguna1
# ..        ...        ...                   ...
# 303        95         50       @teknologihutan
# 304       110         65     @hydrogenfuelcell
# 305        95         50    @pertanianinovatif
# 306       110         65  @greenbuildingexpert
# 307        95         50   @teknologiperkotaan
#
# [308 rows x 6 columns]

# %% [markdown]
# ### Dividing into Languages

# %%
from sklearn.model_selection import train_test_split

# we will "truncate" the dataset
X, _, y, _ = train_test_split(df['text'], df['label'], test_size=0.975, stratify=df['label'], random_state=30)

# we will work with X and y
y.value_counts()
